# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prices=pd.read_csv("/Users/bhavya/Documents/GitHub/AlgoTradingBacktester/Data/prices.csv")
trades=pd.read_csv("/Users/bhavya/Documents/GitHub/AlgoTradingBacktester/Data/trades.csv")

# %%
prices_df=pd.DataFrame(data=prices)
trades_df=pd.DataFrame(data=trades)

# %%
print(prices_df)
# Out:
#       timestamp  bid_price_1  bid_volume_1  bid_price_2  bid_volume_2  \
# 0             0         9998             1       9995.0          30.0
# 1             1         9996             1       9995.0          30.0
# 2             2         9996             1       9995.0          21.0
# 3             3         9996             2       9995.0          23.0
# 4             4         9998             5       9996.0           2.0
# ...         ...          ...           ...          ...           ...
# 9995       9995         9995            28          NaN           NaN
# 9996       9996         9996             2       9995.0          27.0
# 9997       9997         9996             2       9995.0          24.0
# 9998       9998         9995            27          NaN           NaN
# 9999       9999         9996             2       9995.0          21.0
#
#       bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  ask_price_2  \
# ...

# %%
print(sns.pairplot(data=prices_df))

# %%
print(trades_df)
# Out:
#       timestamp  price  quantity
# 0             1  10002         1
# 1             3   9998         2
# 2             3   9998         1
# 3             5  10004         1
# 4             5  10002         1
# ...         ...    ...       ...
# 2402       9976  10002         4
# 2403       9977  10002         1
# 2404       9984  10002         4
# 2405       9988  10002         1
# 2406       9995   9995         2
#
# [2407 rows x 3 columns]

# %%
print(sns.pairplot(data=trades_df))

# %%
print(prices_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     10000 non-null  int64
#  1   bid_price_1   10000 non-null  int64
#  2   bid_volume_1  10000 non-null  int64
#  3   bid_price_2   7460 non-null   float64
#  4   bid_volume_2  7460 non-null   float64
#  5   bid_price_3   1706 non-null   float64
#  6   bid_volume_3  1706 non-null   float64
#  7   ask_price_1   10000 non-null  int64
#  8   ask_volume_1  10000 non-null  int64
#  9   ask_price_2   7447 non-null   float64
#  10  ask_volume_2  7447 non-null   float64
#  11  ask_price_3   1724 non-null   float64
#  12  ask_volume_3  1724 non-null   float64
# dtypes: float64(8), int64(5)
# memory usage: 1015.8 KB
# None

# %%
print(trades_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2407 entries, 0 to 2406
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  2407 non-null   int64
#  1   price      2407 non-null   int64
#  2   quantity   2407 non-null   int64
# dtypes: int64(3)
# memory usage: 56.5 KB
# None
